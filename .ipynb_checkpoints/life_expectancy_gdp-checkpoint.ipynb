# %% [raw]
# #Introduction
# This project will investigate if there is a strong correlation between the economic output of a country and the life expectancy of its citizens.
#
# #Scope of the project
# The goals are:
# + To prepare data,
# + Followed by analysis with plots,
# + Seek to explain the findings from the study.
#
# #Here are a few questions that this project will seek to answer:
#
# + Has life expectancy increased over time in the six nations?
# + Has GDP increased over time in the six nations?
# + Is there a correlation between GDP and life expectancy of a country?
# + What is the average life expectancy in these nations?
# + What is the distribution of that life expectancy?
#
# #The dataset includes:
# Countries: Chile, China, Germany, Mexico, United States, Zimbabwe
# Metrics: Gross Domestic Product (GDP in USD) and life expectancy at birth (in years)
# Time Range: 2000–2015

# %%
# Importing the packages that will be used in this project
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [raw]
# # Loading the data from all_data.csv using pandas.read_csv()
# We will save the Imported DataFrame to variable named df and do quick inspection using .head()

# %%
df = pd.read_csv('all_data.csv')
df.head()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 3
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
# Inspecting number of columns and rows using .shape
df.shape
# This inspection show 96 rows and 4 columns
# Out:
# (96, 4)

# %%
# Summaring the data and checking null values
# Summary info
print(df.info())

# Check for missing values
print(df.isnull().sum())
# There are no missing values in the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
# None
# Country                             0
# Year                                0
# Life expectancy at birth (years)    0
# GDP                                 0
# dtype: int64

# %%
# Exploring the DataFrame
# Finding countries in the data
countries = df.Country.unique()
print(countries)
# We find out that there are 6 countries and the name of those countries are: 'Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe'
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']

# %%
# Finding Years in the data
years = df.Year.unique()
print(years)
# Years represented in the data are 2000 to 2015
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015]

# %%
# Clean and Prepare Data
# Rename columns for ease
df.rename({'Life expectancy at birth (years)': 'Life_Expectancy'}, axis=1, inplace=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          96 non-null     object
#  1   Year             96 non-null     int64
#  2   Life_Expectancy  96 non-null     float64
#  3   GDP              96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.8+ KB
# None

# %%
# Exploratory Data Analysis
# Overall trend of life expectancy by year
# This line plot shows how life expectancy has changed from 2000 to 2015.
# It helps us compare health progress across countries over time.
sns.lineplot(data=df, x='Year', y='Life_Expectancy', hue='Country')
plt.title('Life Expectancy Over Time')
plt.xlabel('Year')
plt.ylabel('Life Expectancy (Years)')
plt.show()

# %%
# GDP trends over time for each country
# This line plot illustrates economic growth by showing changes in GDP over the years.
# It reveals which countries grew fastest and which lagged behind.
sns.lineplot(data=df, x='Year', y='GDP', hue='Country')
plt.title('GDP Over Time')
plt.xlabel('Year')
plt.ylabel('GDP (US Dollars)')
plt.show()

# %%
# Correlation between GDP and Life Expectancy
# This scatter plot shows the relationship between economic strength and health.
# A positive correlation would suggest that wealthier countries tend to live longer.
sns.scatterplot(data=df, x='GDP', y='Life_Expectancy', hue='Country')
plt.title('GDP vs Life Expectancy')
plt.xlabel('GDP (US Dollars)')
plt.ylabel('Life Expectancy (Years)')
plt.show()

# %%
# Statistical Insight
# Calculate the correlation between GDP and Life Expectancy
# This shows how strongly these two variables are related.
# A value near 1 means a strong positive relationship, near 0 means no relationship.
correlation = df[['GDP', 'Life_Expectancy']].corr()
print("Correlation matrix:\n", correlation)
# Out:
# Correlation matrix:
#                        GDP  Life_Expectancy
# GDP              1.000000         0.343207
# Life_Expectancy  0.343207         1.000000

# %% [raw]
# + This correlation matrix tells us if GDP and life expectancy move together.
# + High positive value (e.g., 0.8+) means as GDP increases, life expectancy tends to rise.
# + A value close to 0 means little to no linear relationship.

# %%
# Calculate average GDP and life expectancy for each country
# This helps us compare the overall economic and health status of the countries in the dataset.
grouped = df.groupby('Country')[['GDP', 'Life_Expectancy']].mean().sort_values(by='GDP', ascending=False)
print("Country-level averages (sorted by GDP):\n", grouped)
# Out:
# Country-level averages (sorted by GDP):
#                                     GDP  Life_Expectancy
# Country
# United States of America  1.407500e+13         78.06250
# China                     4.957714e+12         74.26250
# Germany                   3.094776e+12         79.65625
# Mexico                    9.766506e+11         75.71875
# Chile                     1.697888e+11         78.94375
# Zimbabwe                  9.062580e+09         50.09375

# %% [raw]
# + This shows the average GDP and life expectancy for each country over the 15 years.
# + Sorting by GDP helps us see how economic power compares to health outcomes.
# + It’s a good way to summarize national performance in one table.

# %%
# Create a regression plot showing the trend between GDP and Life Expectancy
# This adds a line of best fit, helping to visualize how well GDP predicts life expectancy.
sns.lmplot(data=df, x='GDP', y='Life_Expectancy', hue='Country', aspect=1.5)
plt.title('Linear Regression: GDP vs Life Expectancy')
plt.xlabel('GDP (US Dollars)')
plt.ylabel('Life Expectancy (Years)')
plt.show()

# %% [raw]
# + The regression lines show how life expectancy changes as GDP increases, for each country.
# + Countries with a steeper slope show a stronger impact of GDP on health.
# + Outliers (like the U.S. or Zimbabwe) can be easily spotted where they don’t follow the trend.

# %% [raw]
# #Conclusion
# After analyzing GDP and life expectancy data from six countries between 2000 and 2015, we can confidently answer the following questions:
#
# 1.Has life expectancy increased over time in the six nations?
# - Yes, life expectancy has steadily increased in all six countries. Countries like Germany and Chile started with high values and continued to improve. Zimbabwe saw the most dramatic improvement, recovering from a health crisis in the early 2000s.
#
# 2.Has GDP increased over time in the six nations?
# - Yes, GDP has generally increased across all six nations, although at very different rates. China and Germany showed strong, consistent growth. Zimbabwe and Haiti (if included) remained economically behind, with more modest increases.
#
# 3.Is there a correlation between GDP and life expectancy of a country?
# - Yes, there is a positive correlation between GDP and life expectancy. Countries with higher GDP tend to have longer life expectancies. However, this relationship isn't perfect — for example, the U.S. has high GDP but does not lead in life expectancy, suggesting that other factors (like healthcare access, social services, and lifestyle) play a role.
#
# 4.What is the average life expectancy in these nations?
# - The average life expectancy ranged from 50 years in Zimbabwe to 80 years in Germany.
#
# 5.What is the distribution of that life expectancy?
# - The distribution of life expectancy is right-skewed:
#     + Most countries have values between 74 and 80 years.
#     + Zimbabwe pulls the average down but is improving rapidly.
# A histogram would show a concentration of values in the high-70s, with Zimbabwe as an outlier.
#
# #Final Thought
# While economic strength (GDP) is clearly linked to better health outcomes, this project reinforces that money alone isn't enough. Effective health policies, equitable access to care, and social development are just as critical to helping people live longer, healthier lives.
